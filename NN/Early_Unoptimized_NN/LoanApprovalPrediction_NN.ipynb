# %%
#Import Dependencies and requirements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

Loan_approval_df = pd.read_csv("../Datasets/ETL_Completed_LoanApprovalPrediction.csv")

# %%
#Check Dataframe has been loaded
Loan_approval_df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        1         1.0          1              0             4583
# 1       1        1         0.0          1              1             3000
# 2       1        1         0.0          0              0             2583
# 3       1        0         0.0          1              0             6000
# 4       1        1         2.0          1              1             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             1508.0       128.0             360.0             1.0
# 1                0.0        66.0             360.0             1.0
# 2             2358.0       120.0             360.0             1.0
# 3                0.0       141.0             360.0             1.0
# 4             4196.0       267.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              0            0
# 1              2            1
# 2              2            1
# 3              2            1
# 4              2            1

# %%
#Get the number of columns of object datatype
obj = (Loan_approval_df.dtypes == 'object')
print("Categorical variables:",len(list(obj[obj].index)))
# Out:
# Categorical variables: 0

# %%
#Check Dataframe has been loaded
Loan_approval_df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        1         1.0          1              0             4583
# 1         1        1         0.0          1              1             3000
# 2         1        1         0.0          0              0             2583
# 3         1        0         0.0          1              0             6000
# 4         1        1         2.0          1              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 500       0        0         0.0          1              0             2900
# 501       1        1         3.0          1              0             4106
# 502       1        1         1.0          1              0             8072
# 503       1        1         2.0          1              0             7583
# 504       0        0         0.0          1              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0               1508.0       128.0             360.0             1.0
# 1                  0.0        66.0             360.0             1.0
# 2               2358.0       120.0             360.0             1.0
# 3                  0.0       141.0             360.0             1.0
# 4               4196.0       267.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 500                0.0        71.0             360.0             1.0
# 501                0.0        40.0             180.0             1.0
# 502              240.0       253.0             360.0             1.0
# 503                0.0       187.0             360.0             1.0
# 504                0.0       133.0             360.0             0.0
#
#      Property_Area  Loan_Status
# 0                0            0
# 1                2            1
# 2                2            1
# 3                2            1
# 4                2            1
# ..             ...          ...
# 500              0            1
# 501              0            1
# 502              2            1
# 503              2            1
# 504              1            0
#
# [505 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split

X = Loan_approval_df.drop(['Loan_Status'],axis=1)
Y = Loan_approval_df['Loan_Status']
X.shape,Y.shape

X_train, X_test, Y_train, Y_test = train_test_split(X, Y,
                                                    random_state=1,
                                                    stratify=Y)
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((378, 11), (127, 11), (378,), (127,))

# %%
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=11))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 80)                960
#
#  dense_41 (Dense)            (None, 30)                2430
#
#  dense_42 (Dense)            (None, 30)                930
#
#  dense_43 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 4,351
# Trainable params: 4,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 2s 3ms/step - loss: 0.6776 - accuracy: 0.6032
# Epoch 2/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6163 - accuracy: 0.7275
# Epoch 3/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5690 - accuracy: 0.7672
# Epoch 4/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5223 - accuracy: 0.8095
# Epoch 5/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4868 - accuracy: 0.8201
# Epoch 6/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4603 - accuracy: 0.8201
# Epoch 7/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4478 - accuracy: 0.8175
# Epoch 8/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4312 - accuracy: 0.8228
# Epoch 9/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4212 - accuracy: 0.8254
# Epoch 10/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4125 - accuracy: 0.8254
# Epoch 11/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4026 - accuracy: 0.8280
# Epoch 12/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3941 - accuracy: 0.8307
# Epoch 13/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3865 - accuracy: 0.8413
# Epoch 14/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3796 - accuracy: 0.8413
# Epoch 15/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3745 - accuracy: 0.8545
# Epoch 16/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3687 - accuracy: 0.8413
# Epoch 17/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3598 - accuracy: 0.8571
# Epoch 18/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3560 - accuracy: 0.8466
# Epoch 19/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3446 - accuracy: 0.8571
# Epoch 20/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3387 - accuracy: 0.8598
# Epoch 21/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3347 - accuracy: 0.8571
# Epoch 22/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3261 - accuracy: 0.8677
# Epoch 23/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3229 - accuracy: 0.8651
# Epoch 24/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3195 - accuracy: 0.8730
# Epoch 25/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3114 - accuracy: 0.8651
# Epoch 26/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3060 - accuracy: 0.8757
# Epoch 27/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2990 - accuracy: 0.8783
# Epoch 28/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2935 - accuracy: 0.8757
# Epoch 29/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2907 - accuracy: 0.8836
# Epoch 30/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2847 - accuracy: 0.8810
# Epoch 31/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2821 - accuracy: 0.8915
# Epoch 32/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2769 - accuracy: 0.8836
# Epoch 33/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2790 - accuracy: 0.8915
# Epoch 34/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2667 - accuracy: 0.8942
# Epoch 35/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2615 - accuracy: 0.9021
# Epoch 36/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2588 - accuracy: 0.8942
# Epoch 37/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2562 - accuracy: 0.9074
# Epoch 38/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2471 - accuracy: 0.9127
# Epoch 39/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2455 - accuracy: 0.8995
# Epoch 40/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2415 - accuracy: 0.9074
# Epoch 41/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2351 - accuracy: 0.9233
# Epoch 42/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2351 - accuracy: 0.9180
# Epoch 43/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2298 - accuracy: 0.9180
# Epoch 44/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2259 - accuracy: 0.9233
# Epoch 45/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2186 - accuracy: 0.9312
# Epoch 46/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2205 - accuracy: 0.9233
# Epoch 47/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2193 - accuracy: 0.9206
# Epoch 48/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2109 - accuracy: 0.9233
# Epoch 49/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2127 - accuracy: 0.9180
# Epoch 50/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2187 - accuracy: 0.9180
# Epoch 51/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2063 - accuracy: 0.9206
# Epoch 52/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2006 - accuracy: 0.9180
# Epoch 53/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1938 - accuracy: 0.9206
# Epoch 54/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1994 - accuracy: 0.9233
# Epoch 55/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1916 - accuracy: 0.9365
# Epoch 56/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.9312
# Epoch 57/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1803 - accuracy: 0.9339
# Epoch 58/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1764 - accuracy: 0.9392
# Epoch 59/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1737 - accuracy: 0.9365
# Epoch 60/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1738 - accuracy: 0.9365
# Epoch 61/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1699 - accuracy: 0.9444
# Epoch 62/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1688 - accuracy: 0.9339
# Epoch 63/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1650 - accuracy: 0.9312
# Epoch 64/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1567 - accuracy: 0.9418
# Epoch 65/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1564 - accuracy: 0.9444
# Epoch 66/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1530 - accuracy: 0.9418
# Epoch 67/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1510 - accuracy: 0.9471
# Epoch 68/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1495 - accuracy: 0.9444
# Epoch 69/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1445 - accuracy: 0.9444
# Epoch 70/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1446 - accuracy: 0.9418
# Epoch 71/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1449 - accuracy: 0.9444
# Epoch 72/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1437 - accuracy: 0.9365
# Epoch 73/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1370 - accuracy: 0.9497
# Epoch 74/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1365 - accuracy: 0.9418
# Epoch 75/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1323 - accuracy: 0.9444
# Epoch 76/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1348 - accuracy: 0.9471
# Epoch 77/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1267 - accuracy: 0.9550
# Epoch 78/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9497
# Epoch 79/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1250 - accuracy: 0.9550
# Epoch 80/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1210 - accuracy: 0.9603
# Epoch 81/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1170 - accuracy: 0.9683
# Epoch 82/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1144 - accuracy: 0.9577
# Epoch 83/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1144 - accuracy: 0.9577
# Epoch 84/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1176 - accuracy: 0.9524
# Epoch 85/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.9524
# Epoch 86/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1170 - accuracy: 0.9497
# Epoch 87/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1144 - accuracy: 0.9577
# Epoch 88/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1208 - accuracy: 0.9524
# Epoch 89/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1096 - accuracy: 0.9630
# Epoch 90/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1164 - accuracy: 0.9497
# Epoch 91/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1137 - accuracy: 0.9630
# Epoch 92/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1021 - accuracy: 0.9683
# Epoch 93/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0956 - accuracy: 0.9630
# Epoch 94/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1039 - accuracy: 0.9577
# Epoch 95/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1053 - accuracy: 0.9550
# Epoch 96/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0967 - accuracy: 0.9709
# Epoch 97/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0938 - accuracy: 0.9683
# Epoch 98/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0902 - accuracy: 0.9683
# Epoch 99/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0893 - accuracy: 0.9735
# Epoch 100/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0893 - accuracy: 0.9683

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,Y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 4/4 - 0s - loss: 1.5127 - accuracy: 0.7165 - 167ms/epoch - 42ms/step
# Loss: 1.512702226638794, Accuracy: 0.7165354490280151
