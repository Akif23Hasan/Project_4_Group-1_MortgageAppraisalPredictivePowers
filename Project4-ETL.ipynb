# %%
#  Import and read the charity_data.csv.
import pandas as pd
Loan_df = pd.read_csv("LoanApprovalPrediction.csv")
Loan_df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
#Drop Nan values
Loan_df = Loan_df.dropna()

# %%
#Replace Gender 
mapping = {'Male':1, 'Female':0}
Loan_df['Gender'] = Loan_df['Gender'].map(mapping)

# %%
#Replace Loan Status 
mapping = {'Y':1, 'N':0}
Loan_df['Loan_Status'] = Loan_df['Loan_Status'].map(mapping)

# %%
#Replace Graduate Status 
mapping = {'Graduate':1, 'Not Graduate':0}
Loan_df['Education'] = Loan_df['Education'].map(mapping)

# %%
#Replace Married
mapping = {'Yes':1, 'No':0}
Loan_df['Married'] = Loan_df['Married'].map(mapping)
Loan_df['Self_Employed'] = Loan_df['Self_Employed'].map(mapping)
# Out:
#       Loan_ID  Gender Married  Dependents  Education  Self_Employed  \
# 1    LP001003       1     Yes         1.0        NaN              0
# 2    LP001005       1     Yes         0.0        NaN              1
# 3    LP001006       1     Yes         0.0        NaN              0
# 4    LP001008       1      No         0.0        NaN              0
# 5    LP001011       1     Yes         2.0        NaN              1
# ..        ...     ...     ...         ...        ...            ...
# 593  LP002978       0      No         0.0        NaN              0
# 594  LP002979       1     Yes         3.0        NaN              0
# 595  LP002983       1     Yes         1.0        NaN              0
# 596  LP002984       1     Yes         2.0        NaN              0
# 597  LP002990       0      No         0.0        NaN              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
#Map "Property_Area" Dataframe has been loaded
mapping = {'Rural':2, 'Urban':1, 'Semiurban':0}
Loan_df['Property_Area'] = Loan_df['Property_Area'].map(mapping)

# %%
Loan_df
# Out:
# DataFrame 'Loan_df' successfully exported to 'ETL_Completed_LoanApprovalPrediction.csv' as a CSV file.

# %%
output_file_path = 'ETL_Completed_LoanApprovalPrediction.csv'

# Export the DataFrame to a CSV file
Loan_df.to_csv(output_file_path, index=False)

# Printing a message indicating successful export
print(f"DataFrame 'Loan_df' successfully exported to '{output_file_path}' as a CSV file.")
# Out:
# DataFrame 'Loan_df' successfully exported to 'ETL_Completed_LoanApprovalPrediction.csv' as a CSV file.
